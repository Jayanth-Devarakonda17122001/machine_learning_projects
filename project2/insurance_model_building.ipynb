# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Mr\Desktop\netzwork_python\end_to_end_3\insurance.csv',encoding='latin-1')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df = pd.get_dummies(df)

# %%
df
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest',
#        'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
df.drop(['region_northeast','region_northwest','region_southeast','region_southwest'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0   19  27.900         0  16884.92400           1         0          0
# 1   18  33.770         1   1725.55230           0         1          1
# 2   28  33.000         3   4449.46200           0         1          1
# 3   33  22.705         0  21984.47061           0         1          1
# 4   32  28.880         0   3866.85520           0         1          1
#
#    smoker_yes
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %%
x=df.drop(['charges'],axis = 1)
x
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes
# 0      19  27.900         0           1         0          0           1
# 1      18  33.770         1           0         1          1           0
# 2      28  33.000         3           0         1          1           0
# 3      33  22.705         0           0         1          1           0
# 4      32  28.880         0           0         1          1           0
# ...   ...     ...       ...         ...       ...        ...         ...
# 1333   50  30.970         3           0         1          1           0
# 1334   18  31.920         0           1         0          1           0
# 1335   18  36.850         0           1         0          1           0
# 1336   21  25.800         0           1         0          1           0
# 1337   61  29.070         0           1         0          0           1
#
# [1338 rows x 7 columns]

# %%
y=df['charges']
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
sc.fit_transform(x)
# Out:
# array([[-1.43876426, -0.45332   , -0.90861367, ..., -1.0105187 ,
#         -1.97058663,  1.97058663],
#        [-1.50996545,  0.5096211 , -0.07876719, ...,  0.98959079,
#          0.5074631 , -0.5074631 ],
#        [-0.79795355,  0.38330685,  1.58092576, ...,  0.98959079,
#          0.5074631 , -0.5074631 ],
#        ...,
#        [-1.50996545,  1.0148781 , -0.90861367, ..., -1.0105187 ,
#          0.5074631 , -0.5074631 ],
#        [-1.29636188, -0.79781341, -0.90861367, ..., -1.0105187 ,
#          0.5074631 , -0.5074631 ],
#        [ 1.55168573, -0.26138796, -0.90861367, ..., -1.0105187 ,
#         -1.97058663,  1.97058663]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state = 0)

# %% [markdown]
# # MODEL SELECTION

# %%
from sklearn.linear_model import LinearRegression

# %%
insurance_model = LinearRegression()

# %%
insurance_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = insurance_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7978644236809905

# %%
x_test
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes
# 578    52  30.200         1           0         1          1           0
# 610    47  29.370         1           1         0          1           0
# 569    48  40.565         2           0         1          0           1
# 1034   61  38.380         0           0         1          1           0
# 198    51  18.050         0           1         0          1           0
# ...   ...     ...       ...         ...       ...        ...         ...
# 1084   62  30.495         2           1         0          1           0
# 726    41  28.405         1           0         1          1           0
# 1132   57  40.280         0           0         1          1           0
# 725    30  39.050         3           1         0          0           1
# 963    46  24.795         3           0         1          1           0
#
# [268 rows x 7 columns]

# %%
y_test
# Out:
# 578      9724.53000
# 610      8547.69130
# 569     45702.02235
# 1034    12950.07120
# 198      9644.25250
#            ...
# 1084    15019.76005
# 726      6664.68595
# 1132    20709.02034
# 725     40932.42950
# 963      9500.57305
# Name: charges, Length: 268, dtype: float64

# %%
y_pred
# Out:
# array([ 1.14487064e+04,  9.93122532e+03,  3.77727178e+04,  1.59357390e+04,
#         6.88997647e+03,  3.59863726e+03,  1.12708165e+03,  1.40623170e+04,
#         8.76765597e+03,  7.23372702e+03,  4.15287454e+03,  1.01167075e+04,
#         9.08138366e+03,  4.30837572e+03,  2.76879360e+04,  1.11696620e+04,
#         1.11718384e+04,  5.55433485e+03,  8.00873212e+03,  2.66039850e+04,
#         3.34802407e+04,  1.40836906e+04,  1.12578208e+04,  3.25955729e+04,
#         4.51420381e+03,  8.63780775e+03,  7.82347089e+02,  1.01722949e+04,
#         4.25706263e+03,  1.01894544e+04,  8.79010666e+03,  4.03307822e+04,
#         1.58764118e+04,  1.40596765e+04,  2.43874022e+04,  4.70442876e+03,
#         1.29057280e+04,  3.09071751e+04,  3.32583543e+04,  3.87702917e+03,
#         3.64454374e+03,  4.42922762e+03,  3.00771143e+04,  3.91645377e+04,
#         2.80946107e+04,  4.79477036e+03,  1.10638332e+04,  7.65328998e+03,
# ...

# %%
insurance_model.score(x_test,y_test)
# Out:
# 0.7978644236809905

# %%
import pickle

# %% [markdown]
# # creating pickle file for standardscaler

# %%
filename = 'sc.pkl'

# %%
pickle.dump(sc,open(filename,'wb'))

# %% [markdown]
# # creating pickle file for model

# %%
file = 'insurance_charges_predictor.pkl'

# %%
pickle.dump(insurance_model,open(file,'wb'))
